# %%
print('Hello World')
# Out:
# Hello World

# %%
# !ls -l
# Out:
# total 4
# -rw-r--r-- 1 sagemaker-user users 72 May  8 14:06 Untitled.ipynb

# %%
# !pip install Pillow --upgrade
# !pip install numpy --upgrade
# !pip install pandas --upgrade
# !pip install scikit-learn --upgrade
# !pip install psycopg2-binary --upgrade
# !pip install requests --upgrade
# !pip install requests_aws4auth --upgrade
# !pip install pinecone-client --upgrade
# !pip install threadpoolctl==3.1.0
# !pip install numexpr==2.8.4
# !pip install bottleneck==1.3.6
# !pip install seaborn
# Out:
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (9.5.0)
# Collecting Pillow
#   Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 54.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.5.0
#     Uninstalling Pillow-9.5.0:
#       Successfully uninstalled Pillow-9.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-multimodal 0.8.2 requires Pillow<9.6,>=9.3, but you have pillow 10.3.0 which is incompatible.
# Successfully installed Pillow-10.3.0
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (2.1.4)
# Collecting pandas
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 70.5 MB/s eta 0:00:00:00:01:01
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-common 0.8.2 requires pandas<2.2.0,>=2.0.0, but you have pandas 2.2.2 which is incompatible.
# autogluon-core 0.8.2 requires pandas<2.2.0,>=2.0.0, but you have pandas 2.2.2 which is incompatible.
# autogluon-features 0.8.2 requires pandas<2.2.0,>=2.0.0, but you have pandas 2.2.2 which is incompatible.
# autogluon-multimodal 0.8.2 requires pandas<2.2.0,>=2.0.0, but you have pandas 2.2.2 which is incompatible.
# autogluon-multimodal 0.8.2 requires Pillow<9.6,>=9.3, but you have pillow 10.3.0 which is incompatible.
# autogluon-tabular 0.8.2 requires pandas<2.2.0,>=2.0.0, but you have pandas 2.2.2 which is incompatible.
# autogluon-timeseries 0.8.2 requires pandas<2.2.0,>=2.0.0, but you have pandas 2.2.2 which is incompatible.
# autovizwidget 0.21.0 requires pandas<2.0.0,>=0.20.1, but you have pandas 2.2.2 which is incompatible.
# hdijupyterutils 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.2.2 which is incompatible.
# sparkmagic 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.2.2 which is incompatible.
# Successfully installed pandas-2.2.2
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (3.4.0)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Downloading psycopg2_binary-2.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 32.8 MB/s eta 0:00:0000:0100:01
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.9
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests) (2024.2.2)
# Collecting requests_aws4auth
#   Downloading requests_aws4auth-1.2.3-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from requests_aws4auth) (2.31.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from requests_aws4auth) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->requests_aws4auth) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->requests_aws4auth) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->requests_aws4auth) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->requests_aws4auth) (2024.2.2)
# Downloading requests_aws4auth-1.2.3-py2.py3-none-any.whl (24 kB)
# Installing collected packages: requests_aws4auth
# Successfully installed requests_aws4auth-1.2.3
# Collecting pinecone-client
#   Downloading pinecone_client-4.0.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: certifi>=2019.11.17 in /opt/conda/lib/python3.10/site-packages (from pinecone-client) (2024.2.2)
# Requirement already satisfied: tqdm>=4.64.1 in /opt/conda/lib/python3.10/site-packages (from pinecone-client) (4.66.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /opt/conda/lib/python3.10/site-packages (from pinecone-client) (4.5.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.10/site-packages (from pinecone-client) (1.26.18)
# Downloading pinecone_client-4.0.0-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.5/214.5 kB 8.3 MB/s eta 0:00:00
# Installing collected packages: pinecone-client
# Successfully installed pinecone-client-4.0.0
# Collecting threadpoolctl==3.1.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl.metadata (9.2 kB)
# Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Installing collected packages: threadpoolctl
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.4.0
#     Uninstalling threadpoolctl-3.4.0:
#       Successfully uninstalled threadpoolctl-3.4.0
# Successfully installed threadpoolctl-3.1.0
# Collecting numexpr==2.8.4
#   Downloading numexpr-2.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.0 kB)
# Requirement already satisfied: numpy>=1.13.3 in /opt/conda/lib/python3.10/site-packages (from numexpr==2.8.4) (1.26.4)
# Downloading numexpr-2.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (381 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.4/381.4 kB 11.5 MB/s eta 0:00:00
# Installing collected packages: numexpr
# Successfully installed numexpr-2.8.4
# Collecting bottleneck==1.3.6
#   Downloading Bottleneck-1.3.6-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from bottleneck==1.3.6) (1.26.4)
# Downloading Bottleneck-1.3.6-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (354 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.0/354.0 kB 9.2 MB/s eta 0:00:00:00:01
# Installing collected packages: bottleneck
# Successfully installed bottleneck-1.3.6
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/conda/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.10/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/conda/lib/python3.10/site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 7.8 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import boto3

bedrock = boto3.client('bedrock')
response = bedrock.list_foundation_models()
models = response['modelSummaries']
for model in models:
    info = '{:40s}\t{}'.format(model['modelName'], model['modelId'])
    print(info)
# Out:
# Titan Text Large                        	amazon.titan-tg1-large
# Titan Text Embeddings v2                	amazon.titan-embed-g1-text-02
# Titan Text G1 - Lite                    	amazon.titan-text-lite-v1:0:4k
# Titan Text G1 - Lite                    	amazon.titan-text-lite-v1
# Titan Text G1 - Express                 	amazon.titan-text-express-v1:0:8k
# Titan Text G1 - Express                 	amazon.titan-text-express-v1
# Titan Embeddings G1 - Text              	amazon.titan-embed-text-v1:2:8k
# Titan Embeddings G1 - Text              	amazon.titan-embed-text-v1
# Titan Text Embeddings V2                	amazon.titan-embed-text-v2:0:8k
# Titan Text Embeddings V2                	amazon.titan-embed-text-v2:0
# Titan Multimodal Embeddings G1          	amazon.titan-embed-image-v1:0
# Titan Multimodal Embeddings G1          	amazon.titan-embed-image-v1
# Titan Image Generator G1                	amazon.titan-image-generator-v1:0
# Titan Image Generator G1                	amazon.titan-image-generator-v1
# SDXL 1.0                                	stability.stable-diffusion-xl-v1:0
# SDXL 1.0                                	stability.stable-diffusion-xl-v1
# J2 Grande Instruct                      	ai21.j2-grande-instruct
# J2 Jumbo Instruct                       	ai21.j2-jumbo-instruct
# Jurassic-2 Mid                          	ai21.j2-mid
# Jurassic-2 Mid                          	ai21.j2-mid-v1
# Jurassic-2 Ultra                        	ai21.j2-ultra
# Jurassic-2 Ultra                        	ai21.j2-ultra-v1:0:8k
# Jurassic-2 Ultra                        	ai21.j2-ultra-v1
# Claude Instant                          	anthropic.claude-instant-v1:2:100k
# Claude Instant                          	anthropic.claude-instant-v1
# Claude                                  	anthropic.claude-v2:0:18k
# Claude                                  	anthropic.claude-v2:0:100k
# Claude                                  	anthropic.claude-v2:1:18k
# Claude                                  	anthropic.claude-v2:1:200k
# Claude                                  	anthropic.claude-v2:1
# Claude                                  	anthropic.claude-v2
# Claude 3 Sonnet                         	anthropic.claude-3-sonnet-20240229-v1:0:28k
# Claude 3 Sonnet                         	anthropic.claude-3-sonnet-20240229-v1:0:200k
# Claude 3 Sonnet                         	anthropic.claude-3-sonnet-20240229-v1:0
# Claude 3 Haiku                          	anthropic.claude-3-haiku-20240307-v1:0:48k
# Claude 3 Haiku                          	anthropic.claude-3-haiku-20240307-v1:0:200k
# Claude 3 Haiku                          	anthropic.claude-3-haiku-20240307-v1:0
# Claude 3 Opus                           	anthropic.claude-3-opus-20240229-v1:0
# Command                                 	cohere.command-text-v14:7:4k
# Command                                 	cohere.command-text-v14
# Command R                               	cohere.command-r-v1:0
# Command R+                              	cohere.command-r-plus-v1:0
# Command Light                           	cohere.command-light-text-v14:7:4k
# Command Light                           	cohere.command-light-text-v14
# Embed English                           	cohere.embed-english-v3:0:512
# Embed English                           	cohere.embed-english-v3
# Embed Multilingual                      	cohere.embed-multilingual-v3:0:512
# Embed Multilingual                      	cohere.embed-multilingual-v3
# Llama 2 Chat 13B                        	meta.llama2-13b-chat-v1:0:4k
# Llama 2 Chat 13B                        	meta.llama2-13b-chat-v1
# Llama 2 Chat 70B                        	meta.llama2-70b-chat-v1:0:4k
# Llama 2 Chat 70B                        	meta.llama2-70b-chat-v1
# Llama 2 13B                             	meta.llama2-13b-v1:0:4k
# Llama 2 13B                             	meta.llama2-13b-v1
# Llama 2 70B                             	meta.llama2-70b-v1:0:4k
# Llama 2 70B                             	meta.llama2-70b-v1
# Llama 3 8B Instruct                     	meta.llama3-8b-instruct-v1:0
# Llama 3 70B Instruct                    	meta.llama3-70b-instruct-v1:0
# Mistral 7B Instruct                     	mistral.mistral-7b-instruct-v0:2
# Mixtral 8x7B Instruct                   	mistral.mixtral-8x7b-instruct-v0:1
# Mistral Large                           	mistral.mistral-large-2402-v1:0

# %%
import json
import boto3

bedrock = boto3.client(
    service_name='bedrock-runtime'
)

modelId = 'ai21.j2-ultra'
accept = 'application/json'
contentType = 'application/json'
prompt = """
Explain what general relativity is to an 8 year old.
"""
input = {
    'prompt': prompt, 
    'maxTokens': 1024,
    'temperature': 0.3,
    'topP': 1.0,
    'stopSequences': [],
    'countPenalty': {'scale': 0},
    'presencePenalty': {'scale': 0},
    'frequencyPenalty': {'scale': 0}
}
body = json.dumps(input)
response = bedrock.invoke_model(body=body, modelId=modelId, accept=accept, contentType=contentType)
response_body = json.loads(response.get('body').read())
completions = response_body['completions']
for part in completions:
    print(part['data']['text'])
# Out:
# General relativity is a theory of gravity that was developed by Albert Einstein. It says that gravity is not a force like other forces, like magnetism or electricity, but is actually caused by the curvature of space and time. Imagine space and time as a stretchy sheet, and when something big and heavy like a planet or a star is placed on it, it bends the sheet and makes things roll towards it. That's gravity!

# %%
import json
import boto3

bedrock = boto3.client(
    service_name='bedrock-runtime'
)

modelId = 'amazon.titan-text-lite-v1'
accept = 'application/json'
contentType = 'application/json'
prompt = """
Explain what general relativity is to an 8 year old.
"""
input = {
        'inputText': prompt,
        'textGenerationConfig': {
              'maxTokenCount': 1024,
              'stopSequences': [],
              'temperature': 0,
              'topP': 1
        }
    }
body = json.dumps(input)
response = bedrock.invoke_model(body=body, modelId=modelId, accept=accept, contentType=contentType)
response_body = json.loads(response.get('body').read())
completions = response_body['results']
for part in completions:
    print(part['outputText'])
# Out:
# General relativity is a very complicated and interesting part of physics. It explains gravity and space-time. It says that gravity is like a force that pulls things together. It also says that space and time are not just flat things, but they are twisted and bent by gravity. This is why things that are very heavy feel like they are pulling you down, and why the sky looks curved when you are really high up.

# %%
import json
import boto3

bedrock = boto3.client(
    service_name='bedrock-runtime'
)

modelId = 'anthropic.claude-3-sonnet-20240229-v1:0'
accept = 'application/json'
contentType = 'application/json'
prompt = """
Explain what general relativity is to an 8 year old.
"""
user_message = {'role': 'user', 'content': prompt}
messages = [user_message]
input = {
    'anthropic_version': 'bedrock-2023-05-31',
    'max_tokens': 1024,
    'system': '',
    'messages': messages
}
body = json.dumps(input)
response = bedrock.invoke_model(body=body, modelId=modelId)
response_body = json.loads(response.get('body').read())    
body = json.dumps(input)
response = bedrock.invoke_model(body=body, modelId=modelId, accept=accept, contentType=contentType)
response_body = json.loads(response.get('body').read())
completions = response_body['content']
for part in completions:
    print(part['text'])
# Out:
# General relativity is a theory developed by a very smart scientist named Albert Einstein. It explains how gravity works in the universe.
#
# Before Einstein, people thought that gravity was like an invisible force that pulled things together. But Einstein realized that gravity is actually caused by the bending or warping of space and time itself.
#
# Imagine you have a big rubber sheet stretched out flat. If you place a heavy ball in the middle of the sheet, it will cause the rubber to curve or bend inwards, creating a dip or well. That's similar to how massive objects like planets or stars warp the fabric of space and time around them.
#
# Other objects, like smaller balls on the rubber sheet, will roll towards the big ball because of this curve or well in the fabric. This is like how planets and other objects in space get pulled towards massive objects by their gravity.
#
# Einstein's theory shows that really big things with a lot of mass, like black holes or the entire universe, can actually curve space and time so much that it affects how objects move through it. It's a very weird and mind-bending idea, but it helps explain many strange things we see in the cosmos.
#
# Does this help give you a basic idea of what general relativity is about? Let me know if you need any part explained in a simpler way!

# %%
import json
import boto3

bedrock = boto3.client(
    service_name='bedrock-runtime'
)

modelId = 'cohere.command-text-v14'
accept = 'application/json'
contentType = 'application/json'
prompt = """
Explain what general relativity is to an 8 year old.
"""
input = {
    'prompt': prompt, 
    'max_tokens': 1024,
    'temperature': 0.5,
    'k': 500,
    'p': 1.0,
    'stop_sequences': [],
    'return_likelihoods': 'NONE'
}
body = json.dumps(input)
response = bedrock.invoke_model(body=body, modelId=modelId, accept=accept, contentType=contentType)
response_body = json.loads(response.get('body').read())
completions = response_body['generations']
for part in completions:
    print(part['text'])
# Out:
#  General Relativity is a theory developed by Albert Einstein in 1915 that explains how gravity works. General Relativity is an explanation of gravity that is different from the way that gravity has been understood for thousands of years. For example, Newton's Law of Universal Gravitation, which was developed in 1687, describes gravity as a force of attraction between two masses, like a ball on the earth or a moon around the earth.
#
# Einstein's General Relativity describes gravity in a different way and comes up with new predictions that were not explained by Newton's Law. For example, according to Einstein, gravity is not a force, but rather a curvature of space and time.  This is a hard idea to explain, so let's talk about it in terms of a sheet.
#
# You are standing on a sheet. When you sleep, your body creates a small dent in the sheet. Your body is heavy and sinks into the sheet, causing a dent to form. If you make a small object that is very light, like a piece of paper, and you place it on the sheet, it will only sink a tiny bit into the sheet. If you make something very heavy, it will sink into the sheet a lot.
#
# Imagine that the sheet is space and the dents are where large objects, like the sun and the earth, are located. If you were a tiny object, like a planet, you would be curved into the dent created by the sun. This is similar to how planets orbit the sun. The curvature of space-time causes objects to move in certain ways, and this is how gravity works.
#
# General Relativity also explains things that Newton's Law of Universal Gravitation could not explain, like how fast time should pass on different planets, or how much a gravitational wave should stretch space-time. It is a very powerful theory that has been tested many times and has helped scientists understand many things about the universe.
#
# It is important to say that these ideas are very complex and may be hard to understand fully. It is also important to know that scientists are still studying and learning about these topics and there may be things we do not yet know or understand.
#
# This explanation may raise more questions. If you have further questions about General Relativity, or other topics, I will do my best to answer them!

# %%
import json
import boto3

bedrock = boto3.client(
    service_name='bedrock-runtime'
)

modelId = 'meta.llama2-13b-chat-v1'
accept = 'application/json'
contentType = 'application/json'
prompt = """
Explain what general relativity is to an 8 year old.
"""
input = {
    'prompt': prompt,
    'max_gen_len': 512,
    'temperature': 0.5,
    'top_p': 0.9
}
body = json.dumps(input)
response = bedrock.invoke_model(body=body, modelId=modelId, accept=accept, contentType=contentType)
response_body = json.loads(response.get('body').read())
generation = response_body['generation']
print(generation)
# Out:
# I'd be happy to help! Here's an explanation of general relativity that an 8 year old might understand:
#
# Imagine you have a big piece of paper and you draw a map on it. The map shows all the mountains and valleys on the paper. Now imagine that the paper is like the whole universe, and the mountains and valleys are like the stars and planets.
#
# Just like how the map on the paper shows us where the mountains and valleys are, general relativity is a theory that helps us understand how the universe works. It tells us how the stars and planets move and how they are connected to each other.
#
# But here's the really cool thing about general relativity: it tells us that the universe is like a big, stretchy fabric. That means that if you push on one part of the fabric, it will make another part of the fabric move too! It's like if you push on the map, it will make the mountains and valleys move around.
#
# So, general relativity helps us understand how the universe works and how everything is connected. It's a really important theory that scientists use to learn more about the universe and how it was made.
